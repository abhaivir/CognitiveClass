# %% [markdown]
# # Analysis on USArrest Dataset

# %%
# The code was removed by Watson Studio for sharing.
# Out:
#      Location  Murder  Assault  UrbanPop  Rape
# 0     Alabama    13.2      236        58  21.2
# 1      Alaska    10.0      263        48  44.5
# 2     Arizona     8.1      294        80  31.0
# 3    Arkansas     8.8      190        50  19.5
# 4  California     9.0      276        91  40.6

# %%
d_update = df_data.rename(columns ={"UrbanPop":"Theft"})
d_update.head()
# Out:
#      Location  Murder  Assault  Theft  Rape
# 0     Alabama    13.2      236     58  21.2
# 1      Alaska    10.0      263     48  44.5
# 2     Arizona     8.1      294     80  31.0
# 3    Arkansas     8.8      190     50  19.5
# 4  California     9.0      276     91  40.6

# %%
# row count
d_update.shape
# Out:
# (50, 5)

# %%
# checking duplicates
duplicate = d_update[d_update.duplicated()]
duplicate
# Out:
# Empty DataFrame
# Columns: [Location, Murder, Assault, Theft, Rape]
# Index: []

# %%
# got no duplicates! That's good !

# checking for missing values:
d_update.count()
# Out:
# Location    50
# Murder      50
# Assault     50
# Theft       50
# Rape        50
# dtype: int64

# %%
# data is available and balanced

# check for outliers
q1 = d_update.quantile(0.25)
q3 = d_update.quantile(0.75)
IQR = q3-q1
IQR
# Out:
# Murder       7.175
# Assault    140.000
# Theft       23.250
# Rape        11.100
# dtype: float64

# %%
d_update.head(10)
# Out:
#       Location  Murder  Assault  Theft  Rape
# 0      Alabama    13.2      236     58  21.2
# 1       Alaska    10.0      263     48  44.5
# 2      Arizona     8.1      294     80  31.0
# 3     Arkansas     8.8      190     50  19.5
# 4   California     9.0      276     91  40.6
# 5     Colorado     7.9      204     78  38.7
# 6  Connecticut     3.3      110     77  11.1
# 7     Delaware     5.9      238     72  15.8
# 8      Florida    15.4      335     80  31.9
# 9      Georgia    17.4      211     60  25.8

# %%
#scatterplot:

fig, ax = plt.subplots(figsize=(10,5))
ax.scatter(d_update['Theft'],d_update['Murder'])
ax.set_xlabel('Theft')
ax.set_ylabel('Murder')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,5))
ax.scatter(d_update['Theft'],d_update['Rape'])
ax.set_xlabel('Theft')
ax.set_ylabel('Rape')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,5))
ax.scatter(d_update['Theft'],d_update['Assault'])
ax.set_xlabel('Theft')
ax.set_ylabel('Assault')
plt.show()

# %%
# Finding correlation between the criminal attributes

plt.figure(figsize=(10,5))
c = d_update.corr()
sns.heatmap(c,cmap = "BrBG",annot=True)
# Out:
# <AxesSubplot:>

# %%
Here, we can relate that once a crime is initiated (Even a theft), it can convert into more severity and Brutal offence !!!
